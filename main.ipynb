# %% [markdown]
# #### Imports

# %%
import os
import pandas as pd
import pandas_ta as ta
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.logger import configure
from stable_baselines3 import PPO

# %% [markdown]
# #### Local imports

# %%
from add_indicators import add_indicators, normalize_features
from trading_env import CustomStocksWithIndicatorsEnv

from evaluation import EvalProfitCallback, ProfitToTensorboardCallback, make_eval_env

# %% [markdown]
# #### DF Setup

# %%
df = pd.read_csv("data/btc_1m.csv", parse_dates=['timestamp'])
df = add_indicators(df)

df = df.rename(columns={"date": "Date", "open": "Open", "high": "High", "low": "Low", "close": "Close", "volume": "Volume"})
df.set_index("Date", inplace=True)


indicators = ['ema_9', 'ema_21', 'macd', 'rsi_7', 
    'ema_9_slope', 'ema_21_slope',
    'gap', 'high_percent', 'low_percent',
    'atr_14', 'boll', 'boll_ub', 'boll_lb', 'vwap',
    'stoch_k', 'stoch_d', 'adx',
    'obv', 'cmf', 'zscore_close_20', 'rvol', 'cci']
df = normalize_features(df, indicators)

split_index = int(len(df) * 0.9)
df_train = df.iloc[:split_index].copy()
df_eval = df.iloc[split_index - 60:].copy()

# %%
len(df_train), len(df_eval)
# Out:
# (1201899, 133605)

# %% [markdown]
# #### Env setup

# %%
env = CustomStocksWithIndicatorsEnv(df=df_train, window_size=60, frame_bound=(60, len(df_train) - 1), max_episode_steps=2 ** 10, features=indicators)
env.trade_fee_ask_percent = 0.0004
env.trade_fee_bid_percent = 0.0004
env = Monitor(env)

# %% [markdown]
# #### Model

# %%
log_dir = "./ppo_btc_logs/"    


model = PPO(
    "MlpPolicy",
    env,
    n_steps=1024,
    batch_size=128,
    learning_rate=1e-5, 
    gamma=0.9995,
    gae_lambda=0.99,
    ent_coef=0.05,
    vf_coef=0.1,
    max_grad_norm=0.9,
    clip_range=0.2,
    tensorboard_log=log_dir,
    verbose=1,
    normalize_advantage=True
)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# #### Callbacks

# %%
eval_callback = EvalProfitCallback(make_eval_env(df_eval, features=indicators), eval_freq=100_000, n_eval_episodes=1)

# %% [markdown]
# #### Logging

# %%
if not os.path.exists(log_dir):
    #calculate len of folders in log_dir
    os.makedirs(log_dir)
    log_dir = f"{log_dir}run_{len(os.listdir(log_dir)) + 1}/"
else:
    #if log_dir exists, create a new folder with incremented number
    existing_runs = [d for d in os.listdir(log_dir) if os.path.isdir(os.path.join(log_dir, d))]
    run_number = len(existing_runs) + 1
    log_dir = f"{log_dir}run_{run_number}/"

os.makedirs(log_dir, exist_ok=True)

logger = configure(log_dir, ["stdout", "tensorboard"])
model.set_logger(logger)
#delete dir if it exists
# Out:
# Logging to ./ppo_btc_logs/run_13/

# %% [markdown]
# #### Learning

# %%
callback = [eval_callback, ProfitToTensorboardCallback(verbose=0)]

model.learn(total_timesteps=5_000_000, progress_bar=False, callback=callback,)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    buy_and_hold    | 1.63     |
# |    ep_len_mean     | 887      |
# |    ep_rew_mean     | -87.1    |
# |    profit_delta    | -0.934   |
# |    total_profit    | 0.7      |
# | time/              |          |
# |    fps             | 351      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 1024     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 1.79         |
# |    ep_len_mean          | 878          |
# |    ep_rew_mean          | -83.3        |
# |    profit_delta         | -1.09        |
# |    total_profit         | 0.699        |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 2.316432e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | -0.108       |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.84         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000196    |
# |    value_loss           | 53.3         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 3.69          |
# |    ep_len_mean          | 887           |
# |    ep_rew_mean          | -84.4         |
# |    profit_delta         | -2.99         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 333           |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 3.3472315e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0.129         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.36          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000174     |
# |    value_loss           | 57.6          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    buy_and_hold         | 1.56        |
# |    ep_len_mean          | 889         |
# |    ep_rew_mean          | -87.1       |
# |    profit_delta         | -0.856      |
# |    total_profit         | 0.7         |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 4.54369e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 0.322       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 5.18        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000231   |
# |    value_loss           | 54.8        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.61          |
# |    ep_len_mean          | 907           |
# |    ep_rew_mean          | -89.4         |
# |    profit_delta         | -0.91         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 379           |
# |    iterations           | 5             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 6.7615765e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.0479       |
# |    learning_rate        | 1e-05         |
# |    loss                 | 4.95          |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -8.82e-05     |
# |    value_loss           | 56.7          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 4.99         |
# |    ep_len_mean          | 898          |
# |    ep_rew_mean          | -86.7        |
# |    profit_delta         | -4.29        |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 6            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 3.046944e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.529        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 5.22         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000383    |
# |    value_loss           | 57           |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    buy_and_hold         | 1.57           |
# |    ep_len_mean          | 887            |
# |    ep_rew_mean          | -85.7          |
# |    profit_delta         | -0.874         |
# |    total_profit         | 0.7            |
# | time/                   |                |
# |    fps                  | 390            |
# |    iterations           | 7              |
# |    time_elapsed         | 18             |
# |    total_timesteps      | 7168           |
# | train/                  |                |
# |    approx_kl            | 1.47075625e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.693         |
# |    explained_variance   | 0.53           |
# |    learning_rate        | 1e-05          |
# |    loss                 | 3.69           |
# |    n_updates            | 60             |
# |    policy_gradient_loss | -0.000182      |
# |    value_loss           | 47.4           |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.56          |
# |    ep_len_mean          | 896           |
# |    ep_rew_mean          | -86.9         |
# |    profit_delta         | -0.863        |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 404           |
# |    iterations           | 8             |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.3332814e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0.09          |
# |    learning_rate        | 1e-05         |
# |    loss                 | 6.45          |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000225     |
# |    value_loss           | 63.7          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 3.8           |
# |    ep_len_mean          | 894           |
# |    ep_rew_mean          | -85.9         |
# |    profit_delta         | -3.1          |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 418           |
# |    iterations           | 9             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 1.2130593e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0.48          |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.78          |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000211     |
# |    value_loss           | 58.5          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 4.03         |
# |    ep_len_mean          | 905          |
# |    ep_rew_mean          | -87.4        |
# |    profit_delta         | -3.33        |
# |    total_profit         | 0.699        |
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 10           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 5.627866e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | -0.199       |
# |    learning_rate        | 1e-05        |
# |    loss                 | 4.31         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000186    |
# |    value_loss           | 55.9         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 3.63          |
# |    ep_len_mean          | 906           |
# |    ep_rew_mean          | -87.3         |
# |    profit_delta         | -2.93         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 421           |
# |    iterations           | 11            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 2.2949069e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.126        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.06          |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000438     |
# |    value_loss           | 60.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 2.58         |
# |    ep_len_mean          | 902          |
# |    ep_rew_mean          | -86.6        |
# |    profit_delta         | -1.88        |
# |    total_profit         | 0.699        |
# | time/                   |              |
# |    fps                  | 428          |
# |    iterations           | 12           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 3.566849e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.0587       |
# |    learning_rate        | 1e-05        |
# |    loss                 | 4.97         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000206    |
# |    value_loss           | 56.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 6.32          |
# |    ep_len_mean          | 901           |
# |    ep_rew_mean          | -86.7         |
# |    profit_delta         | -5.62         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 436           |
# |    iterations           | 13            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 7.3819538e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.269        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.02          |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000292     |
# |    value_loss           | 60.3          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 2.08         |
# |    ep_len_mean          | 901          |
# |    ep_rew_mean          | -86.5        |
# |    profit_delta         | -1.38        |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 443          |
# |    iterations           | 14           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 6.697769e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 1e-05        |
# |    loss                 | 6.24         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000418    |
# |    value_loss           | 65.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 2.8           |
# |    ep_len_mean          | 903           |
# |    ep_rew_mean          | -87.1         |
# |    profit_delta         | -2.1          |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 440           |
# |    iterations           | 15            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 1.0496646e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.0041       |
# |    learning_rate        | 1e-05         |
# |    loss                 | 4.61          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000187     |
# |    value_loss           | 53.7          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.62          |
# |    ep_len_mean          | 904           |
# |    ep_rew_mean          | -87.3         |
# |    profit_delta         | -0.917        |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 438           |
# |    iterations           | 16            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 1.1764234e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.896        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.91          |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000449     |
# |    value_loss           | 64.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 3.88         |
# |    ep_len_mean          | 902          |
# |    ep_rew_mean          | -87.4        |
# |    profit_delta         | -3.18        |
# |    total_profit         | 0.699        |
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 17           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 6.730552e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.403        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 5.56         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00024     |
# |    value_loss           | 60.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 5.71         |
# |    ep_len_mean          | 901          |
# |    ep_rew_mean          | -87.2        |
# |    profit_delta         | -5.01        |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 447          |
# |    iterations           | 18           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 1.409906e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 4.5          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000125    |
# |    value_loss           | 57.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 2.53         |
# |    ep_len_mean          | 900          |
# |    ep_rew_mean          | -86.3        |
# |    profit_delta         | -1.83        |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 447          |
# |    iterations           | 19           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 1.180399e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.0734       |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.41         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000137    |
# |    value_loss           | 41.1         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 3.83          |
# |    ep_len_mean          | 900           |
# |    ep_rew_mean          | -86.6         |
# |    profit_delta         | -3.13         |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 447           |
# |    iterations           | 20            |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 3.5382574e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0.0957        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.92          |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00055      |
# |    value_loss           | 61.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.4           |
# |    ep_len_mean          | 900           |
# |    ep_rew_mean          | -86.7         |
# |    profit_delta         | -0.705        |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 451           |
# |    iterations           | 21            |
# |    time_elapsed         | 47            |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 1.3072859e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | -0.00858      |
# |    learning_rate        | 1e-05         |
# |    loss                 | 2.95          |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000151     |
# |    value_loss           | 45.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 5.74          |
# |    ep_len_mean          | 898           |
# |    ep_rew_mean          | -86.4         |
# |    profit_delta         | -5.04         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 455           |
# |    iterations           | 22            |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00023113127 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0.446         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 3.7           |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000876     |
# |    value_loss           | 39.5          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 3.89          |
# |    ep_len_mean          | 898           |
# |    ep_rew_mean          | -86.5         |
# |    profit_delta         | -3.19         |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 457           |
# |    iterations           | 23            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 1.3019599e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | -0.574        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 4.21          |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000145     |
# |    value_loss           | 71.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.82          |
# |    ep_len_mean          | 901           |
# |    ep_rew_mean          | -86.1         |
# |    profit_delta         | -1.12         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 455           |
# |    iterations           | 24            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 6.2048784e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | -0.311        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.88          |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000295     |
# |    value_loss           | 65.4          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 2.63          |
# |    ep_len_mean          | 901           |
# |    ep_rew_mean          | -86.2         |
# |    profit_delta         | -1.93         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 456           |
# |    iterations           | 25            |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 3.6173267e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | 0.333         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 3.37          |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000357     |
# |    value_loss           | 43.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.85          |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -86.6         |
# |    profit_delta         | -1.15         |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 26            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.0644959e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | -0.0528       |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.45          |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000213     |
# |    value_loss           | 66            |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 3.75          |
# |    ep_len_mean          | 901           |
# |    ep_rew_mean          | -86.8         |
# |    profit_delta         | -3.05         |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 463           |
# |    iterations           | 27            |
# |    time_elapsed         | 59            |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 2.5434943e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | 0.389         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 6.72          |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000375     |
# |    value_loss           | 71.8          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 4.06          |
# |    ep_len_mean          | 901           |
# |    ep_rew_mean          | -86.7         |
# |    profit_delta         | -3.36         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 461           |
# |    iterations           | 28            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 2.4128123e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.269        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 4.3           |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000471     |
# |    value_loss           | 56.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 4.03          |
# |    ep_len_mean          | 899           |
# |    ep_rew_mean          | -86.8         |
# |    profit_delta         | -3.33         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 459           |
# |    iterations           | 29            |
# |    time_elapsed         | 64            |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 1.3549405e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | 0.473         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.65          |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000414     |
# |    value_loss           | 63.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 3.66          |
# |    ep_len_mean          | 900           |
# |    ep_rew_mean          | -87           |
# |    profit_delta         | -2.96         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 462           |
# |    iterations           | 30            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 5.8065518e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | 0.211         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 4.72          |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000509     |
# |    value_loss           | 55            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 2.1          |
# |    ep_len_mean          | 903          |
# |    ep_rew_mean          | -86.9        |
# |    profit_delta         | -1.4         |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 465          |
# |    iterations           | 31           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 6.973394e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | -0.814       |
# |    learning_rate        | 1e-05        |
# |    loss                 | 7.72         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000347    |
# |    value_loss           | 84.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 5.89          |
# |    ep_len_mean          | 905           |
# |    ep_rew_mean          | -87.2         |
# |    profit_delta         | -5.19         |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 466           |
# |    iterations           | 32            |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00013263029 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | -0.0679       |
# |    learning_rate        | 1e-05         |
# |    loss                 | 3.26          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000676     |
# |    value_loss           | 49.8          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 5.88          |
# |    ep_len_mean          | 905           |
# |    ep_rew_mean          | -87.2         |
# |    profit_delta         | -5.18         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 464           |
# |    iterations           | 33            |
# |    time_elapsed         | 72            |
# |    total_timesteps      | 33792         |
# | train/                  |               |
# |    approx_kl            | 1.6364094e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.691        |
# |    explained_variance   | -0.463        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 3.41          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000109     |
# |    value_loss           | 54.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.33          |
# |    ep_len_mean          | 906           |
# |    ep_rew_mean          | -87.3         |
# |    profit_delta         | -0.631        |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 464           |
# |    iterations           | 34            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00011636893 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | 0.249         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.39          |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000303     |
# |    value_loss           | 57.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 3.09         |
# |    ep_len_mean          | 904          |
# |    ep_rew_mean          | -87.4        |
# |    profit_delta         | -2.39        |
# |    total_profit         | 0.699        |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 35           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 1.542503e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | 0.619        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.65         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000129    |
# |    value_loss           | 53.6         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.61          |
# |    ep_len_mean          | 903           |
# |    ep_rew_mean          | -87.6         |
# |    profit_delta         | -0.91         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 468           |
# |    iterations           | 36            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 5.5977667e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | 0.646         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 7.13          |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000503     |
# |    value_loss           | 76.6          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.83          |
# |    ep_len_mean          | 903           |
# |    ep_rew_mean          | -87.6         |
# |    profit_delta         | -1.13         |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 462           |
# |    iterations           | 37            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 37888         |
# | train/                  |               |
# |    approx_kl            | 1.0962365e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.101        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 4.88          |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000234     |
# |    value_loss           | 54.1          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 5.09         |
# |    ep_len_mean          | 904          |
# |    ep_rew_mean          | -88.1        |
# |    profit_delta         | -4.39        |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 38           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 1.691078e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | -1.2         |
# |    learning_rate        | 1e-05        |
# |    loss                 | 6.35         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000274    |
# |    value_loss           | 86.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 4.94          |
# |    ep_len_mean          | 904           |
# |    ep_rew_mean          | -88.1         |
# |    profit_delta         | -4.25         |
# |    total_profit         | 0.698         |
# | time/                   |               |
# |    fps                  | 435           |
# |    iterations           | 39            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 39936         |
# | train/                  |               |
# |    approx_kl            | 1.5447906e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | -0.346        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 3.28          |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000227     |
# |    value_loss           | 49.8          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 2.59         |
# |    ep_len_mean          | 903          |
# |    ep_rew_mean          | -88.1        |
# |    profit_delta         | -1.89        |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 428          |
# |    iterations           | 40           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 7.961702e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | -0.488       |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.78         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000211    |
# |    value_loss           | 54.4         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 3.15          |
# |    ep_len_mean          | 904           |
# |    ep_rew_mean          | -88.2         |
# |    profit_delta         | -2.45         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 426           |
# |    iterations           | 41            |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 41984         |
# | train/                  |               |
# |    approx_kl            | 8.5625215e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.0835       |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.2           |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000325     |
# |    value_loss           | 58.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.64          |
# |    ep_len_mean          | 905           |
# |    ep_rew_mean          | -88.2         |
# |    profit_delta         | -0.945        |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 424           |
# |    iterations           | 42            |
# |    time_elapsed         | 101           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 5.5881683e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.693        |
# |    explained_variance   | -0.217        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 4.71          |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000229     |
# |    value_loss           | 60.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 5.05          |
# |    ep_len_mean          | 904           |
# |    ep_rew_mean          | -88.3         |
# |    profit_delta         | -4.35         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 419           |
# |    iterations           | 43            |
# |    time_elapsed         | 104           |
# |    total_timesteps      | 44032         |
# | train/                  |               |
# |    approx_kl            | 0.00016900385 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | -0.0562       |
# |    learning_rate        | 1e-05         |
# |    loss                 | 4.63          |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000777     |
# |    value_loss           | 51.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.56          |
# |    ep_len_mean          | 904           |
# |    ep_rew_mean          | -88.4         |
# |    profit_delta         | -0.862        |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 416           |
# |    iterations           | 44            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 5.0190138e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | 0.591         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 6.02          |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000287     |
# |    value_loss           | 61            |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.42          |
# |    ep_len_mean          | 902           |
# |    ep_rew_mean          | -88.6         |
# |    profit_delta         | -0.723        |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 415           |
# |    iterations           | 45            |
# |    time_elapsed         | 110           |
# |    total_timesteps      | 46080         |
# | train/                  |               |
# |    approx_kl            | 1.1500146e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.692        |
# |    explained_variance   | -0.765        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 8.28          |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000331     |
# |    value_loss           | 83.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 2.62          |
# |    ep_len_mean          | 903           |
# |    ep_rew_mean          | -88.4         |
# |    profit_delta         | -1.92         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 409           |
# |    iterations           | 46            |
# |    time_elapsed         | 115           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 1.2473902e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.691        |
# |    explained_variance   | -2.98         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 4.49          |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -6.22e-05     |
# |    value_loss           | 68.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 3.93         |
# |    ep_len_mean          | 904          |
# |    ep_rew_mean          | -88.1        |
# |    profit_delta         | -3.23        |
# |    total_profit         | 0.7          |
# | time/                   |              |
# ...
# |    explained_variance   | 0.751         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 2.38          |
# |    n_updates            | 2400          |
# |    policy_gradient_loss | -0.000605     |
# |    value_loss           | 36.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.69          |
# |    ep_len_mean          | 909           |
# |    ep_rew_mean          | -85.3         |
# |    profit_delta         | -0.987        |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 188           |
# |    iterations           | 242           |
# |    time_elapsed         | 1317          |
# |    total_timesteps      | 247808        |
# | train/                  |               |
# |    approx_kl            | 0.00022230239 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.687        |
# |    explained_variance   | 0.742         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 2.19          |
# |    n_updates            | 2410          |
# |    policy_gradient_loss | -0.000856     |
# |    value_loss           | 46.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 6.01         |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | -84.9        |
# |    profit_delta         | -5.31        |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 188          |
# |    iterations           | 243          |
# |    time_elapsed         | 1319         |
# |    total_timesteps      | 248832       |
# | train/                  |              |
# |    approx_kl            | 4.327565e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | -0.15        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.56         |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.000697    |
# |    value_loss           | 40.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 1.65         |
# |    ep_len_mean          | 906          |
# |    ep_rew_mean          | -84.9        |
# |    profit_delta         | -0.953       |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 189          |
# |    iterations           | 244          |
# |    time_elapsed         | 1321         |
# |    total_timesteps      | 249856       |
# | train/                  |              |
# |    approx_kl            | 5.478767e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | -0.0457      |
# |    learning_rate        | 1e-05        |
# |    loss                 | 2.53         |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.000336    |
# |    value_loss           | 39.2         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.6           |
# |    ep_len_mean          | 906           |
# |    ep_rew_mean          | -84.8         |
# |    profit_delta         | -0.899        |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 189           |
# |    iterations           | 245           |
# |    time_elapsed         | 1323          |
# |    total_timesteps      | 250880        |
# | train/                  |               |
# |    approx_kl            | 2.8783688e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.686        |
# |    explained_variance   | 0.0395        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 2.85          |
# |    n_updates            | 2440          |
# |    policy_gradient_loss | -0.000412     |
# |    value_loss           | 38.8          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 3.71          |
# |    ep_len_mean          | 907           |
# |    ep_rew_mean          | -85.1         |
# |    profit_delta         | -3.01         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 189           |
# |    iterations           | 246           |
# |    time_elapsed         | 1326          |
# |    total_timesteps      | 251904        |
# | train/                  |               |
# |    approx_kl            | 9.8261546e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.687        |
# |    explained_variance   | 0.613         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 4.53          |
# |    n_updates            | 2450          |
# |    policy_gradient_loss | -0.00106      |
# |    value_loss           | 45.8          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 1.59         |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -85.2        |
# |    profit_delta         | -0.893       |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 190          |
# |    iterations           | 247          |
# |    time_elapsed         | 1328         |
# |    total_timesteps      | 252928       |
# | train/                  |              |
# |    approx_kl            | 6.659236e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | 0.5          |
# |    learning_rate        | 1e-05        |
# |    loss                 | 2.76         |
# |    n_updates            | 2460         |
# |    policy_gradient_loss | -0.000848    |
# |    value_loss           | 34.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.61          |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | -85.4         |
# |    profit_delta         | -0.908        |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 190           |
# |    iterations           | 248           |
# |    time_elapsed         | 1330          |
# |    total_timesteps      | 253952        |
# | train/                  |               |
# |    approx_kl            | 0.00021774421 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.687        |
# |    explained_variance   | -0.047        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.46          |
# |    n_updates            | 2470          |
# |    policy_gradient_loss | -0.000853     |
# |    value_loss           | 65.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 1.82         |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | -85.6        |
# |    profit_delta         | -1.12        |
# |    total_profit         | 0.699        |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 249          |
# |    time_elapsed         | 1332         |
# |    total_timesteps      | 254976       |
# | train/                  |              |
# |    approx_kl            | 0.0013813509 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | -0.00415     |
# |    learning_rate        | 1e-05        |
# |    loss                 | 5.09         |
# |    n_updates            | 2480         |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 49           |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.67          |
# |    ep_len_mean          | 907           |
# |    ep_rew_mean          | -85.6         |
# |    profit_delta         | -0.966        |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 191           |
# |    iterations           | 250           |
# |    time_elapsed         | 1334          |
# |    total_timesteps      | 256000        |
# | train/                  |               |
# |    approx_kl            | 5.5364915e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.689        |
# |    explained_variance   | -0.319        |
# |    learning_rate        | 1e-05         |
# |    loss                 | 4.36          |
# |    n_updates            | 2490          |
# |    policy_gradient_loss | -0.000633     |
# |    value_loss           | 61.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.78          |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | -85.7         |
# |    profit_delta         | -1.08         |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 192           |
# |    iterations           | 251           |
# |    time_elapsed         | 1336          |
# |    total_timesteps      | 257024        |
# | train/                  |               |
# |    approx_kl            | 4.0616113e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.688        |
# |    explained_variance   | -1.43         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 1.66          |
# |    n_updates            | 2500          |
# |    policy_gradient_loss | -0.000552     |
# |    value_loss           | 45.3          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 2.61          |
# |    ep_len_mean          | 909           |
# |    ep_rew_mean          | -85.9         |
# |    profit_delta         | -1.91         |
# |    total_profit         | 0.699         |
# | time/                   |               |
# |    fps                  | 192           |
# |    iterations           | 252           |
# |    time_elapsed         | 1338          |
# |    total_timesteps      | 258048        |
# | train/                  |               |
# |    approx_kl            | 0.00022473407 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.688        |
# |    explained_variance   | 0.328         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 5.83          |
# |    n_updates            | 2510          |
# |    policy_gradient_loss | -0.00152      |
# |    value_loss           | 59            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 1.4          |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | -85.7        |
# |    profit_delta         | -0.705       |
# |    total_profit         | 0.699        |
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 253          |
# |    time_elapsed         | 1339         |
# |    total_timesteps      | 259072       |
# | train/                  |              |
# |    approx_kl            | 7.574534e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.689       |
# |    explained_variance   | -0.346       |
# |    learning_rate        | 1e-05        |
# |    loss                 | 5.66         |
# |    n_updates            | 2520         |
# |    policy_gradient_loss | -0.000647    |
# |    value_loss           | 62.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 2.64         |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | -85.6        |
# |    profit_delta         | -1.94        |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 254          |
# |    time_elapsed         | 1342         |
# |    total_timesteps      | 260096       |
# | train/                  |              |
# |    approx_kl            | 3.371609e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.689       |
# |    explained_variance   | 0.552        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 2.09         |
# |    n_updates            | 2530         |
# |    policy_gradient_loss | -0.000843    |
# |    value_loss           | 31.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    buy_and_hold         | 5.05         |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | -85.6        |
# |    profit_delta         | -4.35        |
# |    total_profit         | 0.7          |
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 255          |
# |    time_elapsed         | 1347         |
# |    total_timesteps      | 261120       |
# | train/                  |              |
# |    approx_kl            | 0.0005824819 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 5.08         |
# |    n_updates            | 2540         |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 54.3         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    buy_and_hold         | 1.61          |
# |    ep_len_mean          | 906           |
# |    ep_rew_mean          | -85.5         |
# |    profit_delta         | -0.914        |
# |    total_profit         | 0.7           |
# | time/                   |               |
# |    fps                  | 194           |
# |    iterations           | 256           |
# |    time_elapsed         | 1349          |
# |    total_timesteps      | 262144        |
# | train/                  |               |
# |    approx_kl            | 0.00011698445 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.683        |
# |    explained_variance   | 0.93          |
# |    learning_rate        | 1e-05         |
# |    loss                 | 3.42          |
# |    n_updates            | 2550          |
# |    policy_gradient_loss | -0.000498     |
# |    value_loss           | 52.2          |
# -------------------------------------------
